# %%
import random, sys
import numpy as np
from time import time

from gensim.models import atmodel
from gensim.models import AuthorTopicModel

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
from bokeh.models import Legend, Div, PrintfTickFormatter
from bokeh.layouts import column, row

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8cbfed0a-a343-4f49-92a8-d7255e883b08">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Tests of the algorithm on artificially generated data

# %% [markdown]
# ## Test difference between blocking VB and non-blocking VB

# %%
atfilename = '/home/olavur/Dropbox/my_folder/workstuff/DTU/thesis/code/gensim/gensim/models/temp/blocking_vb_tests/atnonblocking.py'
with open(atfilename) as f:
    code = compile(f.read(), atfilename, 'exec')
    exec(code)

# %%
atfilename = '/home/olavur/Dropbox/my_folder/workstuff/DTU/thesis/code/gensim/gensim/models/temp/blocking_vb_tests/atblocking.py'
with open(atfilename) as f:
    code = compile(f.read(), atfilename, 'exec')
    exec(code)

# %%
vocab_size = 1000
num_docs = 100
words_per_doc = 10  # Average unique words per document
word_freq = 10  # Average frequency of each word in document.
word_std = 10.0
corpus = []
for d in range(num_docs):
    ids = random.sample(range(vocab_size), words_per_doc)
    cts = np.random.normal(word_freq, word_std, len(ids))
    cts = [int(np.ceil(abs(cnt))) for cnt in cts]
    doc = list(zip(ids, cts))
    corpus.append(doc)
    
num_authors = 100
def make_author2doc(docs_per_author=10):
    author2doc = {}
    for a in range(num_authors):
        doc_ids = random.sample(range(num_docs), docs_per_author)
        author2doc[a] = doc_ids

    return author2doc

def make_doc2author(authors_per_doc=10):
    doc2author = {}
    for d in range(num_docs):
        author_ids = random.sample(range(num_authors), authors_per_doc)
        doc2author[d] = author_ids

    return doc2author

# %%
num_topics = 5
doc2author = make_doc2author(5)
author2doc = atmodel.construct_author2doc(corpus, doc2author)

# %time nb_model = AtNonBlocking(corpus=corpus, num_topics=num_topics, \
                  author2doc=author2doc, doc2author=doc2author, iterations=5, random_state=0)

# %time b_model = AtBlocking(corpus=corpus, num_topics=num_topics, \
                  author2doc=author2doc, doc2author=doc2author, iterations=5, random_state=0)
# Out:
# CPU times: user 6.13 s, sys: 0 ns, total: 6.13 s
# Wall time: 6.13 s
# CPU times: user 11.6 s, sys: 32 ms, total: 11.6 s
# Wall time: 11.6 s

# %%
authors_per_doc = [len(authors) for authors in nb_model.doc2author.values()]
sum(authors_per_doc) / len(nb_model.doc2author)
# Out:
# 5.0

# %%
docs_per_author = [len(docs) for docs in nb_model.author2doc.values()]
sum(docs_per_author) / len(nb_model.author2doc)
# Out:
# 50.0

# %%
iterations = range(nb_model.iterations)

p1 = figure(title='', x_axis_label='Iterations', y_axis_label='Per word bound')
s1 = p1.line(iterations, nb_model.perwordbound[1:], color='red')
p1.circle(iterations, nb_model.perwordbound[1:], color='red')
s2 = p1.line(iterations, b_model.perwordbound[1:], color='blue')
p1.circle(iterations, b_model.perwordbound[1:], color='blue')
p1.plot_height=400
p1.plot_width=600
p1.toolbar_location = None

show(p1)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e8fc4dcb-b4f4-4b01-bcf2-63e8ca02fc68"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e8fc4dcb-b4f4-4b01-bcf2-63e8ca02fc68").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e8fc4dcb-b4f4-4b01-bcf2-63e8ca02fc68");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e
type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"a89926b0-652f-4dd2-a8f1-b5d590d28ecd","type":"BoxAnnotation"},"plot":{"id":"06497455-af0d-4407-8ae5-324ab4a353b0","subtype":"Figure","type":"Plot"}},"id":"52a86bed-cd74-442f-858a-74d91aaeaeba","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"b1b465f3-9d1a-4b2c-a017-ea19af5bfbae","type":"LinearAxis"}],"left":[{"id":"759402e1-75d2-48d3-983d-c9a7887dfc96","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"b1b465f3-9d1a-4b2c-a017-ea19af5bfbae","type":"LinearAxis"},{"id":"90d3320a-e019-4d67-a91e-3a1a13ec2787","type":"Grid"},{"id":"759402e1-75d2-48d3-983d-c ...

# %%
authors_per_doc = [len(authors) for authors in nb_model.doc2author.values()]
sum(authors_per_doc) / len(nb_model.doc2author)
# Out:
# 5.0

# %%
docs_per_author = [len(docs) for docs in nb_model.author2doc.values()]
sum(docs_per_author) / len(nb_model.author2doc)
# Out:
# 5.05050505050505

# %%
iterations = range(nb_model.iterations)

p1 = figure(title='', x_axis_label='Iterations', y_axis_label='Per word bound')
s1 = p1.line(iterations, nb_model.perwordbound[1:], color='red')
p1.circle(iterations, nb_model.perwordbound[1:], color='red')
s2 = p1.line(iterations, b_model.perwordbound[1:], color='blue')
p1.circle(iterations, b_model.perwordbound[1:], color='blue')
p1.plot_height=400
p1.plot_width=600
p1.toolbar_location = None

show(p1)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c6040a95-31ea-4b26-bef4-5dd9f1e4d2f3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c6040a95-31ea-4b26-bef4-5dd9f1e4d2f3").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c6040a95-31ea-4b26-bef4-5dd9f1e4d2f3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c6040a95-31ea-4b26-bef4-5dd9f1e4d2f3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"228a7707-be34-4603-9079-8b2bbc87c066":{"roots":{"references":[{"attributes":{"overlay":{"id":"bc6f967d-cd67-4922-a9ec-af68bb832dab","type":"BoxAnnotation"},"plot":{"id":"be5c0c88-b445-40cf-af44-b54e2df00572","subtype":"Figure","type":"Plot"}},"id":"0d23ea42-3748-4727-aa30-7756a0b367c9","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"be5c0c88-b445-40cf-af44-b54e2df00572","subtype":"Figure","type":"Plot"}},"id":"6a53b3a7-d0b1-4ec5-9d8e-59fa38c21c76","type":"SaveTool"},{"attributes":{"data_source":{"id":"d7217d53-fa08-4965-bc35-6529c5c81220","type":"ColumnDataSource"},"glyph":{"id":"36a21ae0-1c12-484c-a5f7-970500acbcd1","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"0661cde3-e294-4408-98e9-ab594509a22a","type":"Line"},"selection_glyph":null},"id":"7cfae798-694c-4b3b-bc27-1fff24f29744","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"78e7a56a-9ded-4b30-86d0-095253253318","type":"PanTool"},{"id":"42f6f3b3-ec05-455c-a34e-7f01ed1f1142","type":"WheelZoomTool"},{"id":"0d23ea42-3748-4727-aa30-7756a0b367c9","type":"BoxZoomTool"},{"id":"6a53b3a7-d0b1-4ec5-9d8e-59fa38c21c76","type":"SaveTool"},{"id":"07fe9bc4-53bc-4a64-89dc-f95940c185d7","type":"ResetTool"},{"id":"56d66d8f-d0b5-4ab0-be1d-881ffb29a449","type":"HelpTool"}]},"id":"47289be7-1e23-4304-8feb-24941dca447e","type":"Toolbar"},{"attributes":{"axis_label":"Iterations","formatter":{"id":"8b54f24e-5c68-4d43-9cb4-ea8c9fdc2704","type":"BasicTickFormatter"},"plot":{"id":"be5c0c88-b445-40cf-af44-b54e2df00572","subtype":"Figure","type":"Plot"},"ticker":{"id":"09acdb19-d9f9-4fc8-835b-64cf87f70f44","type":"BasicTicker"}},"id":"6ad42791-783a-4970-92b3-f9d521824ebb","type":"LinearAxis"},{"attributes":{"plot":{"id":"be5c0c88-b445-40cf-af44-b54e2df00572","subtype":"Figure","type":"Plot"}},"id":"42f6f3b3-ec05-455c-a34e-7f01ed1f1142","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"be36ec51-b2f0-43a1-bb37-cb5bd7226664","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bc6f967d-cd67-4922-a9ec-af68bb832dab","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0661cde3-e294-4408-98e9-ab594509a22a","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2b8bd029-fc27-45f9-ae88-689c1e257891","type":"Circle"},{"attributes":{"axis_label":"Per word bound","formatter":{"id":"0b846954-1f3f-429a-a50c-22ce28400344","type":"BasicTickFormatter"},"plot":{"id":"be5c0c88-b445-40cf-af44-b54e2df00572","subtype":"Figure","type":"Plot"},"ticker":{"id":"539f600d-6387-47df-aff9-ddc7a74cbf89","type":"BasicTicker"}},"id":"a469b039-1807-4cfa-8fcd-eec7782137df","type":"LinearAxis"},{"attributes":{},"id":"09acdb19-d9f9-4fc8-835b-64cf87f70f44","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"61765d39-c41b-48c5-8d85-340007f98e60","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"40dd2c4f-668a-402a-8fba-8b6352f7dfef","type":"Line"},{"attributes":{},"id":"8b54f24e-5c68-4d43-9cb4-ea8c9fdc2704","type":"BasicTickFormatter"},{"attributes":{},"id":"539f600d-6387-47df-aff9-ddc7a74cbf89","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4],"y":[ ...

# %% [markdown]
# ## Scalability
#
# ### W.r.t. number of authors

# %%
vocab_size = 1000
num_docs = 100
words_per_doc = 10  # Average unique words per document
word_freq = 10  # Average frequency of each word in document.
word_std = 10.0
corpus = []
for d in range(num_docs):
    ids = random.sample(range(vocab_size), words_per_doc)
    cts = np.random.normal(word_freq, word_std, len(ids))
    cts = [int(np.ceil(abs(cnt))) for cnt in cts]
    doc = list(zip(ids, cts))
    corpus.append(doc)
    
def make_author2doc(docs_per_author=10, num_authors=100):
    author2doc = {}
    for a in range(num_authors):
        doc_ids = random.sample(range(num_docs), docs_per_author)
        author2doc[a] = doc_ids

    return author2doc

def make_doc2author(authors_per_doc=10, num_authors=100):
    doc2author = {}
    for d in range(num_docs):
        author_ids = random.sample(range(num_authors), authors_per_doc)
        doc2author[d] = author_ids

    return doc2author

# %%
num_topics = 5
num_authors_list = [100, 200, 400, 800, 1000]
authors_per_doc = 5
chunksize = len(corpus) + 1

# %%
# %%time
# Time the entire process.

train_time = []
eval_time = []
for num_authors in num_authors_list:
    doc2author = make_doc2author(authors_per_doc, num_authors)
    author2doc = atmodel.construct_author2doc(corpus, doc2author)
    
    # Get training time.
    avg_elapsed = 0.0
    for _ in range(10):
        start = time()
        model = AuthorTopicModel(corpus=corpus, num_topics=num_topics, \
                        author2doc=author2doc, doc2author=doc2author, chunksize=chunksize, \
                        iterations=10, passes=10, eval_every=0, random_state=1)
        avg_elapsed += time() - start
    avg_elapsed /= 10
    train_time.append(avg_elapsed)
    
    # Get evaluation time.
    avg_elapsed = 0.0
    for _ in range(10):
        start = time()
        perwordbound = model.bound(corpus, author2doc=author2doc, doc2author=doc2author)
        avg_elapsed += time() - start
    avg_elapsed /= 10
    eval_time.append(avg_elapsed)
# Out:
# CPU times: user 1min 12s, sys: 16 ms, total: 1min 12s
# Wall time: 1min 12s

# %%
p1 = figure(title='Train time', x_axis_label='Num authors', y_axis_label='Time (sec)')
s1 = p1.line(num_authors_list, train_time)
p1.circle(num_authors_list, train_time)
p1.plot_height=400
p1.plot_width=400
p1.toolbar_location = None

p2 = figure(title='Evaluation time', x_axis_label='Num authors', y_axis_label='Time (sec)')
s2 = p2.line(num_authors_list, eval_time)
p2.circle(num_authors_list, eval_time)
p2.plot_height=400
p2.plot_width=400
p2.toolbar_location = None

plots = row(p1, p2)

show(plots)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="7427d70d-9758-4799-80d2-2759a096dc24"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#7427d70d-9758-4799-80d2-2759a096dc24").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7427d70d-9758-4799-80d2-2759a096dc24");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7427d70d-9758-4799-80d2-2759a096dc24' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d92402f3-e46f-48f6-a4fd-4c1110a43777":{"roots":{"references":[{"attributes":{"plot":{"id":"fd1440e9-084e-4f7a-b165-397818e19350","subtype":"Figure","type":"Plot"}},"id":"4a204220-9390-4d47-8561-99ff4218e917","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"8ba36969-d80d-4b3c-86e5-9a62057681d5","subtype":"Figure","type":"Plot"}},"id":"f1f57f98-c869-4046-b000-2c3ba5af91ef","type":"SaveTool"},{"attributes":{"data_source":{"id":"53ade2db-70e1-49fd-8726-d4542d2a7762","type":"ColumnDataSource"},"glyph":{"id":"efb49426-e0f3-41ad-8a72-8feb767ebc8a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"54dead7f-4404-4e18-9f56-021deba2929d","type":"Line"},"selection_glyph":null},"id":"67b6118f-d265-46ea-a4cd-3f65f9d5f96a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"fd1440e9-084e-4f7a-b165-397818e19350","subtype":"Figure","type":"Plot"}},"id":"de57603f-237a-4158-bf6b-5793f01daab4","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[100,200,400,800,1000],"y":[0.0892869472503662,0.08349497318267822,0.08522779941558838,0.08284721374511719,0.07835142612457276]}},"id":"1cf72fc7-9f52-4df7-93a9-19e2bbcbaa35","type":"ColumnDataSource"},{"attributes":{},"id":"218f81dd-95a0-4469-b2a1-a5ff1c785ab8","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"8ba36969-d80d-4b3c-86e5-9a62057681d5","subtype":"Figure","type":"Plot"},"ticker":{"id":"08f1e565-d430-4811-a1d7-16df826e0741","type":"BasicTicker"}},"id":"db636104-2d61-4c0d-b86b-f44870bec350","type":"Grid"},{"attributes":{"below":[{"id":"98bdc940-ab13-4d90-a158-6232377e2e27","type":"LinearAxis"}],"left":[{"id":"99c7d617-3079-4297-adc2-fb6a4fe3abac","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"98bdc940-ab13-4d90-a158-6232377e2e27","type":"LinearAxis"},{"id":"59d8f11e-a10c-4f18-8307-1e57fc8a266a","type":"Grid"},{"id":"99c7d617-3079-4297-adc2-fb6a4fe3abac","type":"LinearAxis"},{"id":"db636104-2d61-4c0d-b86b-f44870bec350","type":"Grid"},{"id":"e68c089d-65cc-4b6a-96d2-68a548471e26","type":"BoxAnnotation"},{"id":"d0526c03-098f-4872-b24f-8db147c3a0ba","type":"GlyphRenderer"},{"id":"a92555f0-8017-435f-979f-a826017e9e58","type":"GlyphRenderer"}],"title":{"id":"0abcb504-c3b6-48bd-8f3d-c7309a0e6ee6","type":"Title"},"tool_events":{"id":"711f753b-0436-44fa-a312-89a04a049b6f","type":"ToolEvents"},"toolbar":{"id":"688df6d6-8da8-4939-bc4c-340ce7a74700","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"fa19446b-5e61-45f3-8bf4-be2cf2f360ed","type":"DataRange1d"},"y_range":{"id":"6a7734d9-9b9e-4e7c-9245-d0ca804a30cf","type":"DataRange1d"}},"id":"8ba36969-d80d-4b3c-86e5-9a62057681d5","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"fd1440e9-084e-4f7a-b165-397818e19350","subtype":"Figure","type":"Plot"}},"id":"30818187-ca2b-4b36-9072-2ecf23ae6a48","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e68c089d-65cc-4b6a-96d2-68a548471e26","type":"BoxAnnotation"},{"attributes":{},"id":"0efc80fa-e894-43e5-a72c-8b98b398256f","type":"ToolEvents"},{"attributes":{"data_source":{"id":"7d5c0d96-8305-4eb5-82c3-f6bb5169b276","type":"ColumnDataSource"},"glyph":{"id":"1464fb59-e246-4922-ae74-dec134fbeb5a","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"5713ab79-e825-4619-a59f-5fc62143dbb1","type":"Circle"},"selection_glyph":null},"id":"46766220-d56b-4114-b0ab-5bd67166e31b","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"aa156183-e39f-41c5-98c6-6f9e6600e540","type":"LinearAxis"}],"left":[{"id":"bef90ee4-23d6-4205-8cdf-acf450c2114c","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"aa156183-e39f-41c5-98c6-6f9e6600e540","type":"LinearAxis"},{"id ...

# %% [markdown]
# ### W.r.t. number of authors PER document
#
# Number of authors is constant.

# %%
vocab_size = 1000
num_docs = 100
words_per_doc = 10  # Average unique words per document
word_freq = 10  # Average frequency of each word in document.
word_std = 10.0
corpus = []
for d in range(num_docs):
    ids = random.sample(range(vocab_size), words_per_doc)
    cts = np.random.normal(word_freq, word_std, len(ids))
    cts = [int(np.ceil(abs(cnt))) for cnt in cts]
    doc = list(zip(ids, cts))
    corpus.append(doc)
    
def make_author2doc(docs_per_author=10, num_authors=100):
    author2doc = {}
    for a in range(num_authors):
        doc_ids = random.sample(range(num_docs), docs_per_author)
        author2doc[a] = doc_ids

    return author2doc

def make_doc2author(authors_per_doc=10, num_authors=100):
    doc2author = {}
    for d in range(num_docs):
        author_ids = random.sample(range(num_authors), authors_per_doc)
        doc2author[d] = author_ids

    return doc2author

# %%
num_topics = 5
num_authors = 1000
authors_per_doc_list = [5**i for i in range(4)]
chunksize = len(corpus) + 1

# %%
# %%time
# Time the entire process.

train_time = []
eval_time = []
for authors_per_doc in authors_per_doc_list:
    doc2author = make_doc2author(authors_per_doc, num_authors)
    author2doc = atmodel.construct_author2doc(corpus, doc2author)
    
    # Get training time.
    avg_elapsed = 0.0
    for _ in range(1):
        start = time()
        model = AuthorTopicModel(corpus=corpus, num_topics=num_topics, \
                        author2doc=author2doc, doc2author=doc2author, chunksize=chunksize, \
                        iterations=10, passes=10, eval_every=0, random_state=1)
        avg_elapsed += time() - start
    avg_elapsed /= 1
    train_time.append(avg_elapsed)
    
    # Get evaluation time.
    avg_elapsed = 0.0
    for _ in range(1):
        start = time()
        perwordbound = model.bound(corpus, author2doc=author2doc, doc2author=doc2author)
        avg_elapsed += time() - start
    avg_elapsed /= 1
    eval_time.append(avg_elapsed)
# Out:
# 96
# 383
# 924
# 1000
# CPU times: user 12.1 s, sys: 36 ms, total: 12.1 s
# Wall time: 12.1 s

# %%
p1 = figure(title='Train time', x_axis_label='Num authors', y_axis_label='Time (sec)')
s1 = p1.line(authors_per_doc_list, train_time)
p1.circle(authors_per_doc_list, train_time)
p1.plot_height=400
p1.plot_width=400
p1.toolbar_location = None

p2 = figure(title='Evaluation time', x_axis_label='Num authors', y_axis_label='Time (sec)')
s2 = p2.line(authors_per_doc_list, eval_time)
p2.circle(authors_per_doc_list, eval_time)
p2.plot_height=400
p2.plot_width=400
p2.toolbar_location = None

plots = row(p1, p2)

show(column(Div(text='<h3>Sclability w.r.t. number of authors per document</h3>'), plots))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="150226f0-ea9b-49ea-90bc-145e95aa0d0d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#150226f0-ea9b-49ea-90bc-145e95aa0d0d").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("150226f0-ea9b-49ea-90bc-145e95aa0d0d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '150226f0-ea9b-49ea-90bc-145e95aa0d0d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"67020132-3776-464e-b81a-28520e0deb66":{"roots":{"references":[{"attributes":{"callback":null},"id":"8fa72ba6-780b-4a2d-9896-3f9ba308656c","type":"DataRange1d"},{"attributes":{},"id":"41a0d4a9-89ae-483e-8c6b-cbbe47bb5edf","type":"BasicTickFormatter"},{"attributes":{},"id":"37980307-8c4a-4e9d-9912-39a07c4d51a7","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,5,25,125],"y":[0.7472043037414551,1.3959202766418457,3.0598337650299072,5.8207361698150635]}},"id":"c56797ec-1e1f-4b5f-aafe-9abd9910b470","type":"ColumnDataSource"},{"attributes":{"axis_label":"Time (sec)","formatter":{"id":"ed362f0a-0c88-40cf-b0ea-933a0bd4bc10","type":"BasicTickFormatter"},"plot":{"id":"3e2dc46a-baba-4786-b8a1-9e1b6483e201","subtype":"Figure","type":"Plot"},"ticker":{"id":"7aac9d02-275b-4e99-97ab-5a9d83f6de02","type":"BasicTicker"}},"id":"497aae31-022d-4c31-a30e-fc0366123eaa","type":"LinearAxis"},{"attributes":{"data_source":{"id":"3f161af3-b64c-45b1-843a-12a634a6c6e8","type":"ColumnDataSource"},"glyph":{"id":"e33ed96a-48ba-4258-8a91-93ae5b3513b7","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"7a6b6849-c287-4e97-b26f-b3c17ca09352","type":"Circle"},"selection_glyph":null},"id":"1051da5d-e2c5-4d33-a3ae-6b409ee7217a","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"Train time"},"id":"2654cb08-8e10-41a5-a953-8e6fab027016","type":"Title"},{"attributes":{"axis_label":"Num authors","formatter":{"id":"819da2ed-844f-4538-b97f-278cc7ca2974","type":"BasicTickFormatter"},"plot":{"id":"3e2dc46a-baba-4786-b8a1-9e1b6483e201","subtype":"Figure","type":"Plot"},"ticker":{"id":"d52447dc-fafa-4748-827f-589a301bc658","type":"BasicTicker"}},"id":"d308fb12-2ca8-4b25-ada0-a1c79d16fb35","type":"LinearAxis"},{"attributes":{"plot":{"id":"3e2dc46a-baba-4786-b8a1-9e1b6483e201","subtype":"Figure","type":"Plot"}},"id":"734d32ff-15dd-4bf1-ac0d-cd67b712d858","type":"ResetTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ee8b498b-7285-4054-a267-69fa6f4fed2f","type":"Line"},{"attributes":{},"id":"f2cc36e1-3aac-4816-8751-f7ab0cd21f84","type":"ToolEvents"},{"attributes":{"plot":{"id":"3e2dc46a-baba-4786-b8a1-9e1b6483e201","subtype":"Figure","type":"Plot"}},"id":"3be2269b-b61e-4602-bfd5-b11b01ef6229","type":"HelpTool"},{"attributes":{"axis_label":"Num authors","formatter":{"id":"41a0d4a9-89ae-483e-8c6b-cbbe47bb5edf","type":"BasicTickFormatter"},"plot":{"id":"fbbfb57d-6098-4440-beb7-5d78296527dc","subtype":"Figure","type":"Plot"},"ticker":{"id":"952d315c-7b4b-4d66-b2e8-376a4bce8d55","type":"BasicTicker"}},"id":"dfcb3717-3ab6-44fd-87e6-ff402921a39a","type":"LinearAxis"},{"attributes":{"axis_label":"Time (sec)","formatter":{"id":"dd4acae2-45a9-41e0-b3d6-20e95ac52e4e","type":"BasicTickFormatter"},"plot":{"id":"fbbfb57d-6098-4440-beb7-5d78296527dc","subtype":"Figure","type":"Plot"},"ticker":{"id":"56a68724-26ba-47b5-b54c-22c299f19c76","type":"BasicTicker"}},"id":"ce3da2d9-ab64-4275-84d7-7e5b22a20989","type":"LinearAxis"},{"attributes":{"plot":{"id":"3e2dc46a-baba-4786-b8a1-9e1b6483e201","subtype":"Figure","type":"Plot"}},"id":"ba9e101d-fa99-4b18-9dbe-f63ea8150594","type":"PanTool"},{"attributes":{"plot":{"id":"fbbfb57d-6098-4440-beb7-5d78296527dc","subtype":"Figure","type":"Plot"},"ticker":{"id":"952d315c-7b4b-4d66-b2e8-376a4bce8d55","type":"BasicTicker"}},"id":"596385e1-8f08-4bb3-87c0-495dd8f81792","type":"Grid"},{"attributes":{"below":[{"id":"dfcb3717-3ab6-44fd-87e6-ff402921a39a","type":"LinearAxis"}],"left":[{"id":"ce3da2d9-ab64-4275-84d7-7e5b22a20989","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"dfcb3717-3ab6-44fd-87e6-ff402921a39a","type":"LinearAxis"},{"id":"596385e1-8f08-4bb3-87c0-495dd8f81792","type":"Grid"},{"id":"ce3da2d9-ab64-4275-84d7-7e5b22a20989","type":"LinearAxis"},{"id":"eff8294c-cbce-4e64-b5bb-50158983b6c0","type":"Grid"},{"id":"1526c5de-bea8-4a4e-9f43-49462e1abcf5","type":"Box ...

# %% [markdown]
# ### W.r.t. number of documents

# %%
# %%time

# Set some parameters.
num_authors = 1000
authors_per_doc = 5
num_topics = 5
vocab_size = 1000
words_per_doc = 10  # Average unique words per document
word_freq = 10  # Average frequency of each word in document.
word_std = 10.0
num_docs_list = [100, 1000, 10000, 100000]

def make_doc2author(authors_per_doc=10, num_authors=100):
    doc2author = {}
    for d in range(num_docs):
        author_ids = random.sample(range(num_authors), authors_per_doc)
        doc2author[d] = author_ids

    return doc2author


# Generate corpus.
corpus_big = []
for d in range(num_docs_list[-1]):
    ids = random.sample(range(vocab_size), words_per_doc)
    cts = np.random.normal(word_freq, word_std, len(ids))
    cts = [int(np.ceil(abs(cnt))) for cnt in cts]
    doc = list(zip(ids, cts))
    corpus_big.append(doc)

train_time = []
eval_time = []
memory_footprint = []
for num_docs in num_docs_list:
    # Run tests.
    
    # Construct dictionaries.
    doc2author = make_doc2author(authors_per_doc, num_authors)
    author2doc = atmodel.construct_author2doc(corpus, doc2author)
    
    corpus = random.sample(corpus_big, num_docs)
    memory_footprint.append(sys.getsizeof(corpus))
    
    chunksize = len(corpus) + 1
    
    # Get training time.
    avg_elapsed = 0.0
    for _ in range(1):
        start = time()
        model = AuthorTopicModel(corpus=corpus, num_topics=num_topics, \
                        author2doc=author2doc, doc2author=doc2author, chunksize=chunksize, \
                        iterations=10, passes=10, eval_every=0, random_state=1)
        avg_elapsed += time() - start
    avg_elapsed /= 1
    train_time.append(avg_elapsed)
    
    # Get evaluation time.
    avg_elapsed = 0.0
    for _ in range(1):
        start = time()
        perwordbound = model.bound(corpus, author2doc=author2doc, doc2author=doc2author)
        avg_elapsed += time() - start
    avg_elapsed /= 1
    eval_time.append(avg_elapsed)
# Out:
# CPU times: user 34min 38s, sys: 4.3 s, total: 34min 42s
# Wall time: 34min 48s

# %%
p1 = figure(title='Train time', x_axis_label='Size of corpus (bytes)', y_axis_label='Time (sec)', \
            x_axis_type='log', x_range=(10**2, 10**6))
s1 = p1.line(memory_footprint, train_time)
p1.circle(memory_footprint, train_time)
p1.plot_height=400
p1.plot_width=400
p1.toolbar_location = None

p2 = figure(title='Evaluation time', x_axis_label='Size of corpus (bytes)', y_axis_label='Time (sec)',\
           x_axis_type='log', x_range=(10**2, 10**6))
s2 = p2.line(memory_footprint, eval_time)
p2.circle(memory_footprint, eval_time)
p2.plot_height=400
p2.plot_width=400
p2.toolbar_location = None

plots = row(p1, p2)

show(column(Div(text='<h3>Sclability w.r.t. number of documents</h3>'), plots))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0eac6f8e-43d2-4478-b466-971819fda957"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#0eac6f8e-43d2-4478-b466-971819fda957").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0eac6f8e-43d2-4478-b466-971819fda957");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0eac6f8e-43d2-4478-b466-971819fda957' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2eae8562-48c2-4b01-a9e5-5f8f0bdfbe09":{"roots":{"references":[{"attributes":{"below":[{"id":"1ce81a87-3e5e-43ee-a044-528fc525b9af","type":"LogAxis"}],"left":[{"id":"78478ae4-e0b8-45f5-8727-e4d63d922ee0","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"1ce81a87-3e5e-43ee-a044-528fc525b9af","type":"LogAxis"},{"id":"b20c489b-1801-4ec8-b8e4-96bad1a3ce2b","type":"Grid"},{"id":"78478ae4-e0b8-45f5-8727-e4d63d922ee0","type":"LinearAxis"},{"id":"8a90cc03-7632-4017-8d34-2811eb6681c2","type":"Grid"},{"id":"678064cd-5612-4c64-bf61-c431fbac2dcb","type":"BoxAnnotation"},{"id":"9205b722-c463-44a2-afce-973d8028dc90","type":"GlyphRenderer"},{"id":"a2c48cc0-4158-4ae3-8608-4ac9044aa400","type":"GlyphRenderer"}],"title":{"id":"56e94d2a-8e53-4f00-8adf-a789a9bd2eec","type":"Title"},"tool_events":{"id":"5606f1aa-a07a-4c80-b6db-3f8c3a936bfc","type":"ToolEvents"},"toolbar":{"id":"c8ffb395-7aa2-4083-b72c-dc09c2d16f70","type":"Toolbar"},"toolbar_location":null,"x_mapper_type":
type":"LinearAxis"},{"attributes":{"plot":null,"text":"Evaluation time"},"id":"56e94d2a-8e53-4f00-8adf-a789a9bd2eec","t ...

# %%
print(num_docs_list)
print(memory_footprint)

# %% [markdown]
# ### W.r.t. size of vocab

# %%
# %%time

# Set some parameters.
num_authors = 1000
authors_per_doc = 5
num_topics = 5
vocab_size_list = [10, 100, 1000, 10000, 100000]
words_per_doc = 10  # Average unique words per document
word_freq = 10  # Average frequency of each word in document.
word_std = 10.0
num_docs = 100

def make_doc2author(authors_per_doc=10, num_authors=100):
    doc2author = {}
    for d in range(num_docs):
        author_ids = random.sample(range(num_authors), authors_per_doc)
        doc2author[d] = author_ids

    return doc2author


train_time = []
eval_time = []
for vocab_size in vocab_size_list:
    # Run tests.
    
    # Generate corpus.
    corpus = []
    for d in range(num_docs):
        ids = random.sample(range(vocab_size), words_per_doc)
        cts = np.random.normal(word_freq, word_std, len(ids))
        cts = [int(np.ceil(abs(cnt))) for cnt in cts]
        doc = list(zip(ids, cts))
        corpus.append(doc)
    
    # Construct dictionaries.
    doc2author = make_doc2author(authors_per_doc, num_authors)
    author2doc = atmodel.construct_author2doc(corpus, doc2author)
    
    chunksize = len(corpus) + 1
    
    # Get training time.
    avg_elapsed = 0.0
    for _ in range(1):
        start = time()
        model = AuthorTopicModel(corpus=corpus, num_topics=num_topics, \
                        author2doc=author2doc, doc2author=doc2author, chunksize=chunksize, \
                        iterations=10, passes=10, eval_every=0, random_state=1)
        avg_elapsed += time() - start
    avg_elapsed /= 1
    train_time.append(avg_elapsed)
    
    # Get evaluation time.
    avg_elapsed = 0.0
    for _ in range(10):
        start = time()
        perwordbound = model.bound(corpus, author2doc=author2doc, doc2author=doc2author)
        avg_elapsed += time() - start
    avg_elapsed /= 10
    eval_time.append(avg_elapsed)
# Out:
# CPU times: user 20.8 s, sys: 64 ms, total: 20.9 s
# Wall time: 20.9 s

# %%
p1 = figure(title='Train time', x_axis_label='Size of vocab', y_axis_label='Time (sec)', \
            x_axis_type='log', x_range=(1e0, 1e6), y_axis_type='log')
s1 = p1.line(vocab_size_list, train_time)
p1.circle(vocab_size_list, train_time)
p1.plot_height=400
p1.plot_width=400
p1.toolbar_location = None

p2 = figure(title='Evaluation time', x_axis_label='Size of vocab', y_axis_label='Time (sec)',\
           x_axis_type='log', x_range=(1e0, 1e6), y_axis_type='log')
s1 = p2.line(vocab_size_list, eval_time)
p2.circle(vocab_size_list, eval_time)
p2.plot_height=400
p2.plot_width=400
p2.toolbar_location = None

plots = row(p1, p2)

show(column(Div(text='<h3>Sclability w.r.t. size of vocabulary</h3>'), plots))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="42c01de2-82c2-4633-ba39-b1559a9861b4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#42c01de2-82c2-4633-ba39-b1559a9861b4").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("42c01de2-82c2-4633-ba39-b1559a9861b4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '42c01de2-82c2-4633-ba39-b1559a9861b4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"46265fb5-fc55-4fc4-a130-5624910e1770":{"roots":{"references":[{"attributes":{"plot":{"id":"90ea49d1-cb81-4c48-9775-24ee55ac2e08","subtype":"Figure","type":"Plot"}},"id":"5a64f229-8650-47ce-94f7-de816ce562be","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9bf4dfac-2743-4547-a163-245a3ffbb220","type":"Circle"},{"attributes":{"ticker":null},"id":"0fd8a3a9-9152-4677-869b-e0795bb57e5b","type":"LogTickFormatter"},{"attributes":{"num_minor_ticks":10},"id":"11e27922-1f3e-4dc6-9b4a-c05260c15960","type":"LogTicker"},{"attributes":{"dimension":1,"plot":{"id":
subtype":"Figure","type":"Plot"},"ticker":{"id":"3c237c3e-c38d-490a-88f0-74953a8ded00","type":"LogTicker"}},"id":"0ea495ec-8ded-4076-91ac-a527cf03c9a4","type":"Grid"},{"attributes":{"data_source":{"id":"28d4f22e-17f0-4af3-b799-f969b4067263","type":"ColumnDataSource"},"glyph":{"id":"9bf4dfac-2743-4547-a163-245a3ffbb220","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"beb69772-2b4e-4ddb-8f04-b223c8d3cbbc","type":"Circle"},"selection_glyph":null},"id":"2c7a690d-3886-4ca0-bb17-92c0f46353d8","type":"GlyphRenderer"},{"attributes":{"axis_label":"Size of vocab","formatter":{ ...

# %% [markdown]
# ### W.r.t. number of topics

# %%
# %%time

# Set some parameters.
num_authors = 1000
authors_per_doc = 5
num_topics_list = [5, 25, 125, 625]
vocab_size = 1000
words_per_doc = 10  # Average unique words per document
word_freq = 10  # Average frequency of each word in document.
word_std = 10.0
num_docs = 100

def make_doc2author(authors_per_doc=10, num_authors=100):
    doc2author = {}
    for d in range(num_docs):
        author_ids = random.sample(range(num_authors), authors_per_doc)
        doc2author[d] = author_ids

    return doc2author

# Generate corpus.
corpus = []
for d in range(num_docs):
    ids = random.sample(range(vocab_size), words_per_doc)
    cts = np.random.normal(word_freq, word_std, len(ids))
    cts = [int(np.ceil(abs(cnt))) for cnt in cts]
    doc = list(zip(ids, cts))
    corpus.append(doc)

# Construct dictionaries.
doc2author = make_doc2author(authors_per_doc, num_authors)
author2doc = atmodel.construct_author2doc(corpus, doc2author)

chunksize = len(corpus) + 1

train_time = []
for num_topics in num_topics_list:
    # Get training time.
    avg_elapsed = 0.0
    for _ in range(1):
        start = time()
        model = AuthorTopicModel(corpus=corpus, num_topics=num_topics, \
                        author2doc=author2doc, doc2author=doc2author, chunksize=chunksize, \
                        iterations=10, passes=10, eval_every=0, random_state=1)
        avg_elapsed += time() - start
    avg_elapsed /= 1
    train_time.append(avg_elapsed)
# Out:
# CPU times: user 25.7 s, sys: 56 ms, total: 25.8 s
# Wall time: 25.8 s

# %%
p1 = figure(title='Train time', x_axis_label='Number of topics', y_axis_label='Time (sec)', \
            x_axis_type='log', x_range=(1e0, 2e3), y_axis_type='log')
s1 = p1.line(num_topics_list, train_time)
p1.circle(num_topics_list, train_time)
p1.plot_height=400
p1.plot_width=400
p1.toolbar_location = None


show(column(Div(text='<h3>Sclability w.r.t. number of topics</h3>'), p1))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6485d533-f92c-4e41-b808-2d067e926e26"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#6485d533-f92c-4e41-b808-2d067e926e26").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6485d533-f92c-4e41-b808-2d067e926e26");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6485d533-f92c-4e41-b808-2d067e926e26' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9eb6dbcc-f1f8-4a7f-8f56-b7f5e3eab8ce":{"roots":{"references":[{"attributes":{"text":"<h3>Sclability w.r.t. number of topics</h3>"},"id":"c4540a06-cb2b-4d53-8110-71797d3900b0","type":"Div"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5753a115-b103-48ad-9bd6-fd1ce4ec157f","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"b18061af-5c9d-43d9-a2d2-4bb762501d40","subtype":"Figure","type":"Plot"},"ticker":{"id":"6